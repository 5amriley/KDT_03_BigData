# %% [markdown]
# ## 미국 산업군별 평균 연봉 비교분석 (소분류)

# %%
import pandas as pd
import numpy as np

# %%
filename = './Table.csv'

# %%
us_wageDF = pd.read_csv(filename, skiprows=3, header=0, index_col = 0, skipfooter=11, engine='python')
us_wageDF
# Out:
#                                              Unnamed: 1   1998   1999   2000  \
# Line
# 1                 Wages and salaries per full-time e...  35509  37050  39231
# 2                                   Domestic industries  35427  36974  39166
# 3                                    Private industries  35038  36611  38862
# 4             Agriculture, forestry, fishing, and hu...  20653  20709  22146
# 5                                                Farms1  21652  20888  22568
# ...                                                 ...    ...    ...    ...
# 92                                      State and local  36040  37478  39169
# 93                                   General government  35879  37300  38965
# 94                                            Education  35653  36942  38358
# 95                                               Other8  36137  37715  39684
# 96                              Government enterprises8  38352  40037  42115
#
#        2001   2002   2003   2004   2005   2006  ...   2013   2014   2015  \
# Line                                            ...
# 1     40213  40975  42335  44263  45643  47731  ...  56667  58350  59993
# 2     40102  40859  42201  44117  45493  47565  ...  56258  57883  59500
# 3     39692  40243  41482  43420  44719  46805  ...  55439  57174  58733
# 4     24047  24431  24092  26948  28271  28138  ...  34013  34551  32936
# 5     23945  23975  23159  26823  28448  29117  ...  35144  35127  32402
# ...     ...    ...    ...    ...    ...    ...  ...    ...    ...    ...
# 92    40689  41966  43290  44606  45978  48050  ...  56467  57429  59617
# 93    40403  41742  43051  44360  45715  47794  ...  56078  57058  59168
# 94    39774  40851  42145  43533  44721  46990  ...  54060  54782  56671
# 95    41148  42808  44137  45343  46908  48757  ...  58615  59921  62317
# 96    44700  45004  46525  47887  49497  51466  ...  61835  62502  65846
#
#        2016   2017   2018   2019   2020   2021   2022
# Line
# 1     60826  62726  64700  66728  71479  75726  78465
# 2     60273  62132  64106  66111  71013  75069  77634
# 3     59520  61424  63386  65468  70550  74846  77383
# 4     35479  37104  36705  37548  40668  41216  41936
# 5     33990  35941  34061  34310  37326  37052  37424
# ...     ...    ...    ...    ...    ...    ...    ...
# 92    60319  61882  63801  65556  69457  72407  75407
# 93    59863  61404  63292  65023  68965  71987  75024
# 94    57306  58648  60305  61840  65933  69885  73713
# 95    63099  64900  67071  69054  72687  74491  76542
# 96    66631  68549  70869  72968  76371  78233  80582
#
# [96 rows x 26 columns]

# %%
# 컬럼명 변경
us_wageDF = us_wageDF.rename(columns={'Unnamed: 1':'Category'})
us_wageDF
# Out:
#                                                Category   1998   1999   2000  \
# Line
# 1                 Wages and salaries per full-time e...  35509  37050  39231
# 2                                   Domestic industries  35427  36974  39166
# 3                                    Private industries  35038  36611  38862
# 4             Agriculture, forestry, fishing, and hu...  20653  20709  22146
# 5                                                Farms1  21652  20888  22568
# ...                                                 ...    ...    ...    ...
# 92                                      State and local  36040  37478  39169
# 93                                   General government  35879  37300  38965
# 94                                            Education  35653  36942  38358
# 95                                               Other8  36137  37715  39684
# 96                              Government enterprises8  38352  40037  42115
#
#        2001   2002   2003   2004   2005   2006  ...   2013   2014   2015  \
# Line                                            ...
# 1     40213  40975  42335  44263  45643  47731  ...  56667  58350  59993
# 2     40102  40859  42201  44117  45493  47565  ...  56258  57883  59500
# 3     39692  40243  41482  43420  44719  46805  ...  55439  57174  58733
F.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  96 non-null     object
#  1   1998      96 non-null     int64
#  2   1999      96 non-null     int64
#  3   2000      96 non-null     int64
#  4   2001      96 non-null     int64
#  5   2002      96 non-null     int64
#  6   2003      96 non-null     int64
#  7   2004      96 non-null     int64
#  8   2005      96 non-null     int64
#  9   2006      96 non-null     int64
#  10  2007      96 non-null     int64
#  11  2008      96 non-null     int64
#  12  2009      96 non-null     int64
#  13  2010      96 non-null     int64
#  14  2011      96 non-null     int64
#  15  2012      96 non-null     int64
#  16  2013      96 non-null     int64
#  17  2014      96 non-null     int64
#  18  2015      96 non-null     int64
#  19  2016      96 non-null     int64
#  20  2017      96 non-null     int64
#  21  2018      96 non-null     int64
#  22  2019      96 non-null     int64
#  23  2020      96 non-null     int64
#  24  2021      96 non-null     int64
#  25  2022      96 non-null     int64
# dtypes: int64(25), object(1)
# memory usage: 19.6+ KB

# %%
#for i in range(2000, 2023):
#    us_wageDF[str(i)] = us_wageDF[str(i)].astype('int32')

# %%
us_wageDF.iloc[1, 0]
# Out:
# 'Domestic industries'

# %%
us_wageDF.iloc[2, 0]
# Out:
# '    Private industries'

# %%
us_wageDF.iloc[2, 0].count('\t')
# Out:
# 0

# %%
us_wageDF.iloc[2, 0].count(' ')
# Out:
# 5

# %%
us_wageDF.iloc[3, 0].count(' ')
# Out:
# 12

# %%
us_wageDF.iloc[2, 0].strip()[0]
# Out:
# 'P'

# %%
us_wageDF.iloc[2, 0].find(us_wageDF.iloc[2, 0].strip()[0])
# Out:
# 4

# %%
us_wageDF.iloc[3, 0].find(us_wageDF.iloc[3, 0].strip()[0])
# Out:
# 8

# %%
len(us_wageDF)
# Out:
# 96

# %%
us_wageDF.loc[1]
# Out:
# Category    Domestic industries
# 1998                      35427
# 1999                      36974
# 2000                      39166
# 2001                      40102
# 2002                      40859
# 2003                      42201
# 2004                      44117
# 2005                      45493
# 2006                      47565
# 2007                      49699
# 2008                      51050
# 2009                      51519
# 2010                      52939
# 2011                      54393
# 2012                      55712
# 2013                      56258
# 2014                      57883
# 2015                      59500
# 2016                      60273
# 2017                      62132
# 2018                      64106
# 2019                      66111
# 2020                      71013
# 2021                      75069
# 2022                      77634
# Name: 1, dtype: object

# %%
us_wageDF.index
# Out:
# RangeIndex(start=0, stop=96, step=1)

# %%
indent = []
for idx in range(len(us_wageDF)):
    fst = us_wageDF.iloc[idx, 0].strip()[0]
    indent.append(us_wageDF.iloc[idx, 0].find(fst))
indent[:10]
# Out:
# [12, 0, 4, 8, 12, 12, 8, 12, 12, 12]

# %%
indent.count(12)
# Out:
# 49

# %%
second_mask = [True if indent[i] == 12 else False for i, _ in enumerate(indent)]
second_mask[0] = False   # 'Wages and salaries per full-time equivalent employee' 제외
us_wageDF2 = us_wageDF[second_mask]

# %%
us_wageDF2
# Out:
#                                              Category    1998    1999    2000  \
# 4                                              Farms1   21652   20888   22568
# 5               Forestry, fishing, and related act...   18986   20383   21384
# 7                              Oil and gas extraction   74797   79913   89088
# 8                          Mining, except oil and gas   46326   47595   48457
# 9                       Support activities for mining   44863   46074   48214
# 13                                      Durable goods   41573   43721   46573
# 25                                   Nondurable goods   36014   37479   39464
# 35                                      Durable goods   47581   50171   53582
# 59   85327   86023   88635   91621   93091   98048  100471  104603
# 60  138259  139083  143681  148714  152167  165445  170141  174293
# 62   61443   62542   65032   67155   69285   73108   78060   83066
# 63   55889   55105   56953   60338   62790   66362   70881   75778
# 65   96933   99308  102081  105246  108497  114716  121325  126201
# 66  113288  115342  119199  124155  129207  138177  151778  149170
# 67   89143   89364   91832   94692   97299  103910  109071  113065
# 70   40414   41274   42819   44300   46532   50335   54509   59169
# 71   59113   60437   63019   64800   66801   68541   72602   76379
# 74   66606   67531   68392   69761   71749   75124   78242   80950
# 75   64794   65597   67074   68799   70794   73826   77987   83373
# 76   33842   34574   35366   36545   38016   41692   43880   48025
# 77   26643   27428   27957   28775   29945   32258   33888   36516
# 79   89364   92216   94838   96946  100029  119580  120729  123068
# 80   32113   32564   33330   33446   34426   38886   40239   42869
# 82   38027   38777   39939   40954   42060   46520   50517   49973
# 83   25677   26753   27741   28923   30011   30502   35637   38351
# 87   80998   82984   84740   87559   88482   90645   93165   96073
# 90   72727   67089   71380   74177   74392   77712   76254   74133
# 92   59168   59863   61404   63292   65023   68965   71987   75024
# 95   65846   66631   68549   70869   72968   76371   78233   80582
#
# [48 rows x 26 columns]

# %%
us_wageDF2.iloc[1, 1:]
# Out:
# 1998    18986
# 1999    20383
# 2000    21384
# 2001    24266
# 2002    25438
# 2003    26183
# 2004    27209
# 2005    27931
# 2006    26748
# 2007    27778
# 2008    28509
# 2009    28930
# 2010    29502
# 2011    30586
# 2012    31700
# 2013    32454
# 2014    33756
# 2015    33630
# 2016    37507
# 2017    38680
# 2018    40241
# 2019    41846
# 2020    45291
# 2021    46921
# 2022    47975
# Name: 5, dtype: object

# %%
us_wageDF2.sort_values(by='2000', ascending=False)[['Category', '2000']].head(20)
# Out:
#                                              Category    2000
# 58              Securities, commodity contracts, a...  145514
# 48                            Pipeline transportation   96662
# 7                              Oil and gas extraction   89088
# 66              Computer systems design and relate...   82530
# 55              Information and data processing se...   67292
# 52              Publishing industries (includes so...   65901
# 60              Funds, trusts, and other financial...   65435
# 44                                Rail transportation   63353
# 65                                     Legal services   63113
# 54                Broadcasting and telecommunications   59823
# 53              Motion picture and sound recording...   57351
# 67              Miscellaneous professional, scient...   56526
# 79              Performing arts, spectator sports,...   55996
# 35                                      Durable goods   53582
# 43                                 Air transportation   53231
# 59              Insurance carriers and related act...   52294
# 90                             Government enterprises   52231
# 45                               Water transportation   51516
# 8                          Mining, except oil and gas   48457
# 9                       Support activities for mining   48214

# %%
us_wageDF2.sort_values(by='2022', ascending=False)[['Category', '2022']].head(20)
# Out:
#                                              Category    2022
# 58              Securities, commodity contracts, a...  281549
# 55              Information and data processing se...  219646
# 7                              Oil and gas extraction  201341
# 60              Funds, trusts, and other financial...  174293
# 52              Publishing industries (includes so...  169525
# 48                            Pipeline transportation  154608
# 66              Computer systems design and relate...  149170
# 65                                     Legal services  126201
# 79              Performing arts, spectator sports,...  123068
# 67              Miscellaneous professional, scient...  113065
# 54                Broadcasting and telecommunications  113012
# 57              Federal Reserve banks, credit inte...  111364
# 45                               Water transportation  110331
# 43                                 Air transportation  107274
# 44                                Rail transportation  106669
# 9                       Support activities for mining  104847
# 59              Insurance carriers and related act...  104603
# 35                                      Durable goods  102544
# 53              Motion picture and sound recording...   98209
# 87                                 General government   96073

# %%
us_wageDF2.sort_values(by='2022', ascending=False)[:10].index
# Out:
# Index([58, 55, 7, 60, 52, 48, 66, 65, 79, 67], dtype='int64')

# %%
us_wageDF2.sort_values(by='2022', ascending=False)[:10].index.sort_values()
# Out:
# Index([7, 48, 52, 55, 58, 60, 65, 66, 67, 79], dtype='int64')

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

years = us_wageDF2.columns[1:]    # 'Category' 제거 -> 년도만 남음
indices = us_wageDF2.sort_values(by='2022', ascending=False)[:7].index
labels = {58:'유가 증권, 선물 거래 중개', 55:'데이터 처리 서비스', 7:'석유 / 가스 추출',
        60:'펀드, 신탁 관리', 52:'출판 산업 (신문, 서적, 소프트웨어)', 48:'파이프라인 수송',
        66:'컴퓨터 시스템 디자인', 65:'법률', 79:'미술, 음악, 운동 등등', 67:'과학, 기술직'}
colorlist = ['moccasin', '#55BEEB', '#C7E954', '#EEE4C4', '#DDBEAA', 
             '#328f6c', 'darkturquoise', 'grey', 'yellow', 'cornflowerblue']
linestyles = ['-.', '-', '-.', '-.', '-', '-.', '-', '-.', '-.', '-']
plt.figure(figsize=(30, 20))
plt.title('미국 업종별 정규직 근로자 1인당 임금 추이표 (소분류)', fontsize=50, pad=20)   # pad : 타이틀과 그래프와의 간격
i = 0
for idx in indices:
    plt.plot(years, us_wageDF.iloc[idx, 1:], label=labels[idx], linewidth=7, color=colorlist[i], linestyle=linestyles[i])
    i += 1

plt.grid(axis='y')    # y축만 격자 표시
plt.legend(fontsize=25)
plt.xticks(us_wageDF2.columns[1::2], fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %%
us_wageDF2.columns[1::2]
# Out:
# Index(['1998', '2000', '2002', '2004', '2006', '2008', '2010', '2012', '2014',
#        '2016', '2018', '2020', '2022'],
#       dtype='object')

# %%
us_wageDF2.columns[1:]
# Out:
# Index(['1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
growthDF = pd.DataFrame({'Category':us_wageDF2['Category'], 'growth':(us_wageDF2['2022'] / us_wageDF2['2000'])})

# %%
growthDF.head(10)
# Out:
#                                              Category    growth
# 4                                              Farms1  1.658277
# 5               Forestry, fishing, and related act...  2.243500
# 7                              Oil and gas extraction  2.260024
# 8                          Mining, except oil and gas  1.945271
# 9                       Support activities for mining  2.174617
# 13                                      Durable goods  1.875099
# 25                                   Nondurable goods  1.895373
# 35                                      Durable goods  1.913777
# 36                                   Nondurable goods  2.027923
# 38                    Motor vehicle and parts dealers  1.891150

# %%
growthDF1 = growthDF.sort_values(by='growth', ascending=False)
growthDF1
# Out:
#                                              Category    growth
# 55              Information and data processing se...  3.264073
# 60              Funds, trusts, and other financial...  2.663605
# 52              Publishing industries (includes so...  2.572419
# 47              Transit and ground passenger trans...  2.477148
# 70                Administrative and support services  2.430737
# 83                  Food services and drinking places  2.386497
# 57              Federal Reserve banks, credit inte...  2.358358
# 7                              Oil and gas extraction  2.260024
# 5               Forestry, fishing, and related act...  2.243500
# 79              Performing arts, spectator sports,...  2.197800
# 63              Rental and leasing services and le...  2.191509
# 9                       Support activities for mining  2.174617
# 62                                        Real estate  2.161376
# 75                                          Hospitals  2.157966
# 45                               Water transportation  2.141684
# 87                                 General government  2.112098
# 76              Nursing and residential care facil...  2.089315
# 36                                   Nondurable goods  2.027923
# 43                                 Air transportation  2.015254
# 59              Insurance carriers and related act...  2.000287
# 67              Miscellaneous professional, scient...  2.000230
# 65                                     Legal services  1.999604
# 8                          Mining, except oil and gas  1.945271
# 58              Securities, commodity contracts, a...  1.934859
# 46                               Truck transportation  1.933805
# 92                                 General government  1.925420
# 82                                      Accommodation  1.913794
# 35                                      Durable goods  1.913777
# 95                            Government enterprises8  1.913380
# 25                                   Nondurable goods  1.895373
# 38                    Motor vehicle and parts dealers  1.891150
# 54                Broadcasting and telecommunications  1.889106
# 13                                      Durable goods  1.875099
# 80              Amusements, gambling, and recreati...  1.836010
# 77                                  Social assistance  1.832029
# 71              Waste management and remediation s...  1.818504
# 66              Computer systems design and relate...  1.807464
# 49              Other transportation and support a...  1.781370
# 41                                      Other retail2  1.777589
# 40                         General merchandise stores  1.757374
# 74                    Ambulatory health care services  1.734816
# 53              Motion picture and sound recording...  1.712420
# 44                                Rail transportation  1.683725
# 4                                              Farms1  1.658277
# 39                           Food and beverage stores  1.649180
# 48                            Pipeline transportation  1.599470
# 50                            Warehousing and storage  1.562680
# 90                             Government enterprises  1.419330

# %%
barlabel = ['데이터 처리 서비스', '펀드, 신탁 관리', '출판 산업', '대중교통 및\n지상여객운송',
    '관리직', '요식업', '신용 중개', '석유 / 가스 추출', '임업, 수산업', '미술, 음악, 운동']
barcolor = ['cyan', 'beige', 'moccasin', 'pink', 'purple', 'orange', 'beige', 'green', 'cadetblue', 'gold']
plt.figure(figsize=(20, 10))
plt.title('2000 → 2022 연봉 상승 top 10 산업군', fontsize=30, pad=20)
plt.bar(growthDF1.iloc[:10, 0], growthDF1.iloc[:10, 1], color = barcolor, alpha = 0.5, 
edgecolor = 'black', linewidth = 2.5)
plt.xticks(growthDF1.iloc[:10, 0], barlabel, fontsize=12)
box1 = {'boxstyle': 'square',
        'ec': 'azure',
        'fc': 'skyblue',
        'linestyle': '-.',
        'linewidth': 2}
plt.annotate('3.26배 상승 !!', xy=(0.7, 3.24), xytext=(2, 3.1), 
             arrowprops=dict(facecolor='k', arrowstyle='->', linewidth=2), fontsize=20, bbox=box1)
plt.show()

# %%
barlabel = ['소매업', '제너럴 스토어', '외래 의료 직종', '영화 및 녹음 산업',
            '철도 운송업', '농업', '식료품점', '파이프라인 수송', '창고 및 보관', '공기업']
barcolor = ['#F3C301', '#9E8279', '#E8E1DB', 'pink', 'purple', 'orange', '#FF6933', 'green', 'cadetblue', 'brown']
plt.figure(figsize=(20, 10))
plt.title('2000 → 2022 연봉 상승 worst 10 산업군', fontsize=30, pad=20)
plt.bar(growthDF1.iloc[-10:, 0], growthDF1.iloc[-10:, 1], color = barcolor, alpha = 0.5, 
edgecolor = 'black', linewidth = 2.5)
plt.xticks(growthDF1.iloc[-10:, 0], barlabel, fontsize=12)
box2 = {'boxstyle': 'square',
        'ec': 'black',
        'fc': 'brown',
        'linestyle': '-.',
        'linewidth': 2}
plt.annotate('1.42배 상승..', xy=(9, 1.45), xytext=(8.5, 1.7), 
             arrowprops=dict(facecolor='k', arrowstyle='->', linewidth=2), fontsize=20, bbox=box2)
plt.show()
