# %% [markdown]
# ## 미국 산업군별 평균 연봉 비교분석 (대분류)

# %%
import pandas as pd
import numpy as np

# %%
filename = './Table.csv'

# %%
us_wageDF = pd.read_csv(filename, skiprows=3, header=0, index_col = 0, skipfooter=11, engine='python')
us_wageDF
# Out:
#                                              Unnamed: 1   1998   1999   2000  \
# Line
# 1                 Wages and salaries per full-time e...  35509  37050  39231
# 2                                   Domestic industries  35427  36974  39166
# 3                                    Private industries  35038  36611  38862
# 4             Agriculture, forestry, fishing, and hu...  20653  20709  22146
# 5                                                Farms1  21652  20888  22568
# ...                                                 ...    ...    ...    ...
# 92                                      State and local  36040  37478  39169
# 93                                   General government  35879  37300  38965
# 94                                            Education  35653  36942  38358
# 95                                               Other8  36137  37715  39684
# 96                              Government enterprises8  38352  40037  42115
#
# ...

# %%
# 컬럼명 변경
us_wageDF = us_wageDF.rename(columns={'Unnamed: 1':'Category'})
us_wageDF
# Out:
#                                                Category   1998   1999   2000  \
# Line
# 1                 Wages and salaries per full-time e...  35509  37050  39231
# 2                                   Domestic industries  35427  36974  39166
# 3                                    Private industries  35038  36611  38862
# 4             Agriculture, forestry, fishing, and hu...  20653  20709  22146
# 5                                                Farms1  21652  20888  22568
# ...                                                 ...    ...    ...    ...
# 92                                      State and local  36040  37478  39169
# 93                                   General government  35879  37300  38965
# 94                                            Education  35653  36942  38358
# 95                                               Other8  36137  37715  39684
# 96                              Government enterprises8  38352  40037  42115
#
# ...

# %%
# 인덱스를 RangeIndex로 설정
us_wageDF = us_wageDF.reset_index(drop=True)
us_wageDF
# Out:
#                                              Category   1998   1999   2000  \
# 0               Wages and salaries per full-time e...  35509  37050  39231
# 1                                 Domestic industries  35427  36974  39166
# 2                                  Private industries  35038  36611  38862
# 3           Agriculture, forestry, fishing, and hu...  20653  20709  22146
# 4                                              Farms1  21652  20888  22568
# ..                                                ...    ...    ...    ...
# 91                                    State and local  36040  37478  39169
# 92                                 General government  35879  37300  38965
# 93                                          Education  35653  36942  38358
# 94                                             Other8  36137  37715  39684
# 95                            Government enterprises8  38352  40037  42115
#
# ...

# %%
us_wageDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  96 non-null     object
#  1   1998      96 non-null     int64
#  2   1999      96 non-null     int64
#  3   2000      96 non-null     int64
#  4   2001      96 non-null     int64
#  5   2002      96 non-null     int64
#  6   2003      96 non-null     int64
#  7   2004      96 non-null     int64
#  8   2005      96 non-null     int64
#  9   2006      96 non-null     int64
#  10  2007      96 non-null     int64
#  11  2008      96 non-null     int64
#  12  2009      96 non-null     int64
#  13  2010      96 non-null     int64
#  14  2011      96 non-null     int64
#  15  2012      96 non-null     int64
#  16  2013      96 non-null     int64
#  17  2014      96 non-null     int64
#  18  2015      96 non-null     int64
#  19  2016      96 non-null     int64
# ...

# %%
#for i in range(2000, 2023):
#    us_wageDF[str(i)] = us_wageDF[str(i)].astype('int32')

# %%
us_wageDF.iloc[1, 0]
# Out:
# 'Domestic industries'

# %%
us_wageDF.iloc[2, 0]
# Out:
# '    Private industries'

# %%
us_wageDF.iloc[2, 0].count('\t')
# Out:
# 0

# %%
us_wageDF.iloc[2, 0].count(' ')
# Out:
# 5

# %%
us_wageDF.iloc[3, 0].count(' ')
# Out:
# 12

# %%
us_wageDF.iloc[2, 0].strip()[0]
# Out:
# 'P'

# %%
us_wageDF.iloc[2, 0].find(us_wageDF.iloc[2, 0].strip()[0])
# Out:
# 4

# %%
us_wageDF.iloc[3, 0].find(us_wageDF.iloc[3, 0].strip()[0])
# Out:
# 8

# %%
len(us_wageDF)
# Out:
# 96

# %%
us_wageDF.loc[1]
# Out:
# Category    Domestic industries
# 1998                      35427
# 1999                      36974
# 2000                      39166
# 2001                      40102
# 2002                      40859
# 2003                      42201
# 2004                      44117
# 2005                      45493
# 2006                      47565
# 2007                      49699
# 2008                      51050
# 2009                      51519
# 2010                      52939
# 2011                      54393
# 2012                      55712
# 2013                      56258
# 2014                      57883
# 2015                      59500
# 2016                      60273
# 2017                      62132
# 2018                      64106
# 2019                      66111
# 2020                      71013
# 2021                      75069
# 2022                      77634
# Name: 1, dtype: object

# %%
us_wageDF.index
# Out:
# RangeIndex(start=0, stop=96, step=1)

# %%
indent = []
for idx in range(len(us_wageDF)):
    fst = us_wageDF.iloc[idx, 0].strip()[0]
    indent.append(us_wageDF.iloc[idx, 0].find(fst))
indent[:10]
# Out:
# [12, 0, 4, 8, 12, 12, 8, 12, 12, 12]

# %%
indent.count(8)
# Out:
# 21

# %%
first_mask = [True if indent[i] == 8 else False for i, _ in enumerate(indent)]
us_wageDF1 = us_wageDF[first_mask]

# %%
us_wageDF1
# Out:
#                                              Category   1998   1999   2000  \
# 3           Agriculture, forestry, fishing, and hu...  20653  20709  22146
# 6                                              Mining  52872  55016  58134
# 10                                          Utilities  58266  60361  64772
# 11                                       Construction  35131  36599  38551
# 12                                      Manufacturing  39489  41392  43957
# 34                                    Wholesale trade  45439  47636  50896
# 37                                       Retail trade  24586  25519  26589
# 42                     Transportation and warehousing  35965  37426  39055
# 51                                        Information  53023  58781  62571
# 56                              Finance and insurance  55249  58634  64574
# 61                 Real estate and rental and leasing  33062  34638  37150
# ...

# %%
us_wageDF1.iloc[1, 1:]
# Out:
# 1998     52872
# 1999     55016
# 2000     58134
# 2001     61090
# 2002     61166
# 2003     63487
# 2004     67980
# 2005     73210
# 2006     79118
# 2007     83169
# 2008     88638
# 2009     87267
# 2010     91837
# 2011     97209
# 2012     98620
# 2013     99877
# 2014    104672
# 2015    105540
# 2016    105300
# 2017    104138
# 2018    106352
# 2019    110648
# 2020    113323
# 2021    112315
# 2022    120889
# Name: 6, dtype: object

# %%
us_wageDF1.sort_values(by='2000', ascending=False)
# Out:
#                                              Category   1998   1999   2000  \
# 68           Management of companies and enterprises6  66250  69416  74253
# 10                                          Utilities  58266  60361  64772
# 56                              Finance and insurance  55249  58634  64574
# 51                                        Information  53023  58781  62571
# 64          Professional, scientific, and technica...  54515  57670  62472
# 6                                              Mining  52872  55016  58134
# 34                                    Wholesale trade  45439  47636  50896
# 86                                            Federal  42538  44093  46749
# 12                                      Manufacturing  39489  41392  43957
# 91                                    State and local  36040  37478  39169
# 42                     Transportation and warehousing  35965  37426  39055
# ...

# %%
us_wageDF1.sort_values(by='2022', ascending=False)
# Out:
#                                              Category   1998   1999   2000  \
# 51                                        Information  53023  58781  62571
# 68           Management of companies and enterprises6  66250  69416  74253
# 56                              Finance and insurance  55249  58634  64574
# 10                                          Utilities  58266  60361  64772
# 64          Professional, scientific, and technica...  54515  57670  62472
# 6                                              Mining  52872  55016  58134
# 34                                    Wholesale trade  45439  47636  50896
# 86                                            Federal  42538  44093  46749
# 12                                      Manufacturing  39489  41392  43957
# 61                 Real estate and rental and leasing  33062  34638  37150
# 11                                       Construction  35131  36599  38551
# ...

# %%
us_wageDF1.sort_values(by='2022', ascending=False)[:10].index
# Out:
# Index([51, 68, 56, 10, 64, 6, 34, 86, 12, 61], dtype='int64')

# %%
us_wageDF1.sort_values(by='2022', ascending=False)[:10].index.sort_values()
# Out:
# Index([6, 10, 12, 34, 51, 56, 61, 64, 68, 86], dtype='int64')

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

years = us_wageDF1.columns[1:]
indices = us_wageDF1.sort_values(by='2022', ascending=False)[:10].index
labels = {51:'정보', 68:'회계, 재무', 56:'금융 / 보험', 10:'전력 / 천연가스', 64:'법률 / 과학 등 전문직', 
          6:'석유 / 가스 추출', 34:'도매상', 86:'연방 공무원 (군인 등)', 12:'제조업',61:'부동산 및 임대업'}
colorlist = ['#55BEEB', '#97010E', '#C7E954', 'linen', '#99864D', 
             '#B8CABA', 'darkturquoise', 'oldlace', 'lavenderblush', 'cornflowerblue']
linestyles = ['-', ':', ':', ':', '-', ':', '-', ':', ':', ':']
plt.figure(figsize=(30, 20))
plt.title('미국 업종별 정규직 근로자 1인당 임금 추이표 (대분류)', fontsize=50, pad=20)   # pad : 타이틀과 그래프와의 간격
i = 0
for idx in indices:
    plt.plot(years, us_wageDF.iloc[idx, 1:], label=labels[idx], linewidth=5, c=colorlist[i], linestyle=linestyles[i])
    i += 1
plt.grid(axis='y')    # y축만 격자 표시
plt.legend(fontsize=25)
plt.xticks(us_wageDF1.columns[1::2], fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %%
us_wageDF1.columns[1::2]
# Out:
# Index(['1998', '2000', '2002', '2004', '2006', '2008', '2010', '2012', '2014',
#        '2016', '2018', '2020', '2022'],
#       dtype='object')

# %%
us_wageDF1.columns[1:]
# Out:
# Index(['1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')
